# %% [markdown]
# # Use Socrata API to pull some other open Chicago data, starting with L stop locations
#
#
# # This has been implemented in the library, but i'll leave the notebook in case I want to add functionality

# %%
import os
import sys

import numpy as np
import pandas as pd

import folium
import matplotlib.pyplot as plt

# %matplotlib inline

# Load from lib
# %load_ext autoreload 
# %autoreload 2

# Add library to path 
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from lib.download_data import load_trip_data, load_station_data, query_cta_stations
from lib.visualization import map_stations
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_cta = query_cta_stations()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df_cta.head()
# Out:
#     ada   blue    brn direction_id      g  \
# 0  True  False  False            W  False
# 1  True  False  False            E  False
# 2  True  False  False            N  False
# 3  True  False  False            S  False
# 4  True  False  False            S   True
#
#                                             location map_id      o      p  \
# 0  {'type': 'Point', 'coordinates': [-87.669147, ...  40830  False  False
# 1  {'type': 'Point', 'coordinates': [-87.669147, ...  40830  False  False
# 2  {'type': 'Point', 'coordinates': [-87.680622, ...  40120   True  False
# 3  {'type': 'Point', 'coordinates': [-87.680622, ...  40120   True  False
# 4  {'type': 'Point', 'coordinates': [-87.625826, ...  41120  False  False
#
#     pexp    pnk    red           station_descriptive_name  \
# 0  False   True  False                   18th (Pink Line)
# 1  False   True  False                   18th (Pink Line)
# 2  False  False  False          35th/Archer (Orange Line)
# 3  False  False  False          35th/Archer (Orange Line)
# 4  False  False  False  35th-Bronzeville-IIT (Green Line)
#
#            station_name stop_id                        stop_name      y  \
# 0                  18th   30162         18th (54th/Cermak-bound)  False
# 1                  18th   30161                18th (Loop-bound)  False
# 2           35th/Archer   30022         35th/Archer (Loop-bound)  False
# 3           35th/Archer   30023       35th/Archer (Midway-bound)  False
# 4  35th-Bronzeville-IIT   30214  35-Bronzeville-IIT (63rd-bound)  False
#
#     latitude  longitude
# 0  41.857908 -87.669147
# 1  41.857908 -87.669147
# 2  41.829353 -87.680622
# 3  41.829353 -87.680622
# 4  41.831677 -87.625826

# %%
df_stations = load_station_data()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df_stations.head()
# Out:
#    id                    name     city   latitude  longitude  dpcapacity  \
# 0   2     Buckingham Fountain  Chicago  41.876393 -87.620328          27
# 1   3          Shedd Aquarium  Chicago  41.867226 -87.615355          55
# 2   4          Burnham Harbor  Chicago  41.856268 -87.613348          23
# 3   5  State St & Harrison St  Chicago  41.874053 -87.627716          23
# 4   6          Dusable Harbor  Chicago  41.885041 -87.612794          39
#
#   online_date  Unnamed: 7     online_datetime online_month  online_year  \
# 0  2013-06-10         NaN 2013-06-10 10:43:00      2013-06         2013
# 1  2013-06-10         NaN 2013-06-10 10:44:00      2013-06         2013
# 2  2013-06-10         NaN 2013-06-10 10:46:00      2013-06         2013
# 3  2013-06-10         NaN 2013-06-10 10:46:00      2013-06         2013
# 4  2013-06-10         NaN 2013-06-10 11:18:00      2013-06         2013
#
#    distance_to_closest_L_station
# 0                       0.006503
# 1                       0.011236
# 2                       0.013429
# 3                       0.000237
# 4                       0.013518

# %%
# Distance function
def eucl_d(lat1, lat2, long1, long2):
    return np.sqrt((lat2-lat1)**2 + (long2-long1)**2)
eucl_d(1,2,3,4)
# Out:
# 1.4142135623730951

# %%
df_stations['distance_to_closest_L_station'] = df_stations.apply(lambda x: min(eucl_d(x.latitude, df_cta.latitude, x.longitude, df_cta.longitude)), axis=1)

# %%
df_stations.head()
# Out:
#    id                    name     city   latitude  longitude  dpcapacity  \
# 0   2     Buckingham Fountain  Chicago  41.876393 -87.620328          27
# 1   3          Shedd Aquarium  Chicago  41.867226 -87.615355          55
# 2   4          Burnham Harbor  Chicago  41.856268 -87.613348          23
# 3   5  State St & Harrison St  Chicago  41.874053 -87.627716          23
# 4   6          Dusable Harbor  Chicago  41.885041 -87.612794          39
#
#   online_date  Unnamed: 7     online_datetime online_month  online_year  \
# 0  2013-06-10         NaN 2013-06-10 10:43:00      2013-06         2013
# 1  2013-06-10         NaN 2013-06-10 10:44:00      2013-06         2013
# 2  2013-06-10         NaN 2013-06-10 10:46:00      2013-06         2013
# 3  2013-06-10         NaN 2013-06-10 10:46:00      2013-06         2013
# 4  2013-06-10         NaN 2013-06-10 11:18:00      2013-06         2013
#
#    distance_to_closest_L_station
# 0                       0.006503
# 1                       0.011236
# 2                       0.013429
# 3                       0.000237
# 4                       0.013518

# %%
df_stations.sort_values('distance_to_closest_L_station')
# Out:
#       id                                  name      city   latitude  \
# 59    66                  Clinton St & Lake St   Chicago  41.885637
# 40    44                State St & Randolph St   Chicago  41.884730
# 570  611             Oak Park Ave & South Blvd  Oak Park  41.886923
# 415  451              Sheridan Rd & Loyola Ave   Chicago  42.001044
# 63    71                   Morgan St & Lake St   Chicago  41.885483
# 182  201                 Indiana Ave & 40th St   Chicago  41.821680
# 3      5                State St & Harrison St   Chicago  41.874053
# 347  378              California Ave & Lake St   Chicago  41.884454
# 56    60                 Dayton St & North Ave   Chicago  41.910578
# 34    38                    Clark St & Lake St   Chicago  41.886021
# 210  230               Lincoln Ave & Roscoe St   Chicago  41.943340
# 27    31             Franklin St & Chicago Ave   Chicago  41.896776
# 339  368              Ashland Ave & Archer Ave   Chicago  41.839209
# 569  610                Marion St & South Blvd  Oak Park  41.886810
# 346  377                  Kedzie Ave & Lake St   Chicago  41.884603
# 490  531                 Central Ave & Lake St   Chicago  41.887664
# 35    39                 Wabash Ave & Adams St   Chicago  41.879472
# 240  261               Hermitage Ave & Polk St   Chicago  41.871514
# 105  119                 Ashland Ave & Lake St   Chicago  41.885410
# 391  427           Cottage Grove Ave & 63rd St   Chicago  41.780599
# 218  239              Western Ave & Leland Ave   Chicago  41.966555
# 61    68                Clinton St & Tilden St   Chicago  41.875885
# 394  430                   MLK Jr Dr & 63rd St   Chicago  41.780081
# 209  229             Southport Ave & Roscoe St   Chicago  41.943739
# 186  205                  Paulina St & 18th St   Chicago  41.857901
# 62    69                Damen Ave & Pierce Ave   Chicago  41.909396
# 374  410                 Prairie Ave & 43rd St   Chicago  41.816659
# 547 -87.575225          11  2016-05-27         NaN 2016-05-27 11:38:00
# 538 -87.565211          11  2016-05-27         NaN 2016-05-27 11:32:00
# 364 -87.559275          11  2015-01-30         NaN 2015-01-30 17:31:00
# 362 -87.560115          11  2015-01-30         NaN 2015-01-30 17:31:00
# 541 -87.566066           0  2016-05-27         NaN 2016-05-27 11:34:00
# 539 -87.552812          15  2016-05-27         NaN 2016-05-27 11:32:00
# 363 -87.549386          15  2015-01-30         NaN 2015-01-30 17:31:00
# 540 -87.551201           0  2016-05-27         NaN 2016-05-27 11:33:00
#
#     online_month  online_year  distance_to_closest_L_station
# 59       2013-06         2013                       0.000058
# 40       2013-06         2013                       0.000112
# 570      2016-06         2016                       0.000133
# 415      2015-02         2015                       0.000140
# 63       2013-06         2013                       0.000152
# 182      2013-08         2013                       0.000235
# 3        2013-06         2013                       0.000237
# 347      2015-01         2015                       0.000243
# 56       2013-06         2013                       0.000257
# 34       2013-06         2013                       0.000284
# 210      2013-08         2013                       0.000290
# 27       2013-06         2013                       0.000293
# 339      2015-01         2015                       0.000294
# 569      2016-06         2016                       0.000308
# 346      2015-01         2015                       0.000319
# 490      2016-05         2016                       0.000329
# 35       2013-06         2013                       0.000350
# 240      2013-09         2013                       0.000358
# 105      2013-07         2013                       0.000378
# 391      2015-01         2015                       0.000386
# 218      2013-08         2013                       0.000392
# 61       2013-06         2013                       0.000394
# 394      2015-01         2015                       0.000400
# 209      2013-08         2013                       0.000401
# 186      2013-08         2013                       0.000402
# 62       2013-06         2013                       0.000431
# 374      2015-01         2015                       0.000438
# 29       2013-06         2013                       0.000475
# 99       2013-07         2013                       0.000479
# 379      2015-01         2015                       0.000479
# ..           ...          ...                            ...
# 388      2015-01         2015                       0.024709
# 512      2016-05         2016                       0.025659
# 380      2015-01         2015                       0.026282
# 543      2016-05         2016                       0.026827
# 245      2013-09         2013                       0.026952
# 107      2013-07         2013                       0.027113
# 383      2015-01         2015                       0.027289
# 416      2015-02         2015                       0.027482
# 535      2016-05         2016                       0.027574
# 247      2013-09         2013                       0.028780
# 381      2015-01         2015                       0.029099
# 226      2013-08         2013                       0.029227
# 329      2013-10         2013                       0.029506
# 89       2013-07         2013                       0.029746
# 7        2013-06         2013                       0.032429
# 536      2016-05         2016                       0.035637
# 360      2015-01         2015                       0.037931
# 332      2014-01         2014                       0.038918
# 542      2016-05         2016                       0.039156
# 537      2016-05         2016                       0.039525
# 8        2013-06         2013                       0.042506
# 361      2015-01         2015                       0.044919
# 547      2016-05         2016                       0.047565
# 538      2016-05         2016                       0.049636
# 364      2015-01         2015                       0.049983
# 362      2015-01         2015                       0.050570
# 541      2016-05         2016                       0.053406
# 539      2016-05         2016                       0.060253
# 363      2015-01         2015                       0.060765
# 540      2016-05         2016                       0.065283
#
# [585 rows x 12 columns]

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("8mj8-j3c4", limit=2000)

# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df.head()
# Out:
#     ada   blue    brn direction_id      g  \
# 0  True  False  False            W  False
# 1  True  False  False            E  False
# 2  True  False  False            N  False
# 3  True  False  False            S  False
# 4  True  False  False            S   True
#
#                                             location map_id      o      p  \
# 0  {'type': 'Point', 'coordinates': [-87.669147, ...  40830  False  False
# 1  {'type': 'Point', 'coordinates': [-87.669147, ...  40830  False  False
# 2  {'type': 'Point', 'coordinates': [-87.680622, ...  40120   True  False
# 3  {'type': 'Point', 'coordinates': [-87.680622, ...  40120   True  False
# 4  {'type': 'Point', 'coordinates': [-87.625826, ...  41120  False  False
#
#     pexp    pnk    red           station_descriptive_name  \
# 0  False   True  False                   18th (Pink Line)
# 1  False   True  False                   18th (Pink Line)
# 2  False  False  False          35th/Archer (Orange Line)
# 3  False  False  False          35th/Archer (Orange Line)
# 4  False  False  False  35th-Bronzeville-IIT (Green Line)
#
#            station_name stop_id                        stop_name      y
# 0                  18th   30162         18th (54th/Cermak-bound)  False
# 1                  18th   30161                18th (Loop-bound)  False
# 2           35th/Archer   30022         35th/Archer (Loop-bound)  False
# 3           35th/Archer   30023       35th/Archer (Midway-bound)  False
# 4  35th-Bronzeville-IIT   30214  35-Bronzeville-IIT (63rd-bound)  False

# %%
df.location[0]['coordinates'][0]
# Out:
# -87.669147

# %%
df['latitude'] = df.location.map(lambda x: x['coordinates'][1])
df['longitude'] = df.location.map(lambda x: x['coordinates'][0])

# %%
df.head()
# Out:
#     ada   blue    brn direction_id      g  \
# 0  True  False  False            W  False
# 1  True  False  False            E  False
# 2  True  False  False            N  False
# 3  True  False  False            S  False
# 4  True  False  False            S   True
#
#                                             location map_id      o      p  \
# 0  {'type': 'Point', 'coordinates': [-87.669147, ...  40830  False  False
# 1  {'type': 'Point', 'coordinates': [-87.669147, ...  40830  False  False
# 2  {'type': 'Point', 'coordinates': [-87.680622, ...  40120   True  False
# 3  {'type': 'Point', 'coordinates': [-87.680622, ...  40120   True  False
# 4  {'type': 'Point', 'coordinates': [-87.625826, ...  41120  False  False
#
#     pexp    pnk    red           station_descriptive_name  \
# 0  False   True  False                   18th (Pink Line)
# 1  False   True  False                   18th (Pink Line)
# 2  False  False  False          35th/Archer (Orange Line)
# 3  False  False  False          35th/Archer (Orange Line)
# 4  False  False  False  35th-Bronzeville-IIT (Green Line)
#
#            station_name stop_id                        stop_name      y  \
# 0                  18th   30162         18th (54th/Cermak-bound)  False
# 1                  18th   30161                18th (Loop-bound)  False
# 2           35th/Archer   30022         35th/Archer (Loop-bound)  False
# 3           35th/Archer   30023       35th/Archer (Midway-bound)  False
# 4  35th-Bronzeville-IIT   30214  35-Bronzeville-IIT (63rd-bound)  False
#
#     latitude  longitude
# 0  41.857908 -87.669147
# 1  41.857908 -87.669147
# 2  41.829353 -87.680622
# 3  41.829353 -87.680622
# 4  41.831677 -87.625826
